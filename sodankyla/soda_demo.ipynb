# %%
# This notebook shows a simple example how to load the solution file from the SODA
# 
# Octavian Andrei, 2021

# %%
# libraries
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## file in the local directory

# %%
# load data
fin = 'soda2002.csv.gz' # or path where the file resides
df = pd.read_csv(fin)

# %%
df.plot(x='GPST', y='LAT', marker='+', ls='None', figsize=(14,6))
# Out:
# <AxesSubplot:xlabel='GPST'>

# %% [markdown]
# ## from the google drive

# %%
url = 'https://drive.google.com/file/d/1zywIVHSAwKzIn7SDncukCIAivj7pHXXV/view?usp=sharing'
path = 'https://drive.google.com/uc?export=download&id=' + url.split('/')[-2]
df2 = pd.read_csv(fin)
df2.shape
# Out:
# (978147, 8)

# %%
# new figure
fig, axarr = plt.subplots(3,1, figsize=(14,10))

# 
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
cols = ['LAT', 'LON', 'HGT']

#
for i, col in enumerate(cols):
    ax = axarr[i]
    c = colors[i]
    df.plot(ax=ax, x='GPST', y=col, marker='+', ls='None', color=c, rot=0)

fig.tight_layout()
